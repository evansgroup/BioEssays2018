# %%
import pandas as pd
# %matplotlib inline

# %%
dt = pd.read_csv('data/experiments.csv')
dt[['R','Mean Intensity']].hist(bins=10)
dt[dt['Subject']=='s1'][['R','Mean Intensity']].hist(bins=10)
dt[dt['Subject']=='s2'][['R','Mean Intensity']].hist(bins=10)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f99250758d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f9924faf128>]],
#       dtype=object)
